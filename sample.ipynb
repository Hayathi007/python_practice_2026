# %%
print("Hello World!")
# Out:
# Hello World!

# %%
import pandas as pd
lst = ['Greeks', 'For', 'Greeks', 'is', 'portal', 'for', 'Geeks']

df = pd.DataFrame(lst)
print(df)
# Out:
#         0
# 0  Greeks
# 1     For
# 2  Greeks
# 3      is
# 4  portal
# 5     for
# 6   Geeks

# %%
df.drop_duplicates()
# Out:
#         0
# 0  Greeks
# 1     For
# 3      is
# 4  portal
# 5     for
# 6   Geeks

# %%
df.fillna(0)
df.dropna()
# Out:
#         0
# 0  Greeks
# 1     For
# 2  Greeks
# 3      is
# 4  portal
# 5     for
# 6   Geeks
