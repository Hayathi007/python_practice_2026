# %%
name = "Hayathulla kha"
age = 25
salary = 23454.23
print(name)
print(age)
print(salary)

print(type(salary))
# Out:
# Hayathulla kha
# 25
# 23454.23
# <class 'float'>

# %%
city = "Bengaluru"
print(city);
# Out:
# Bengaluru

# %%
a = 10
b = 20
print(a+b)
# Out:
# 30

# %%
a,b,c = ['apple', 'banana', 'cherry']
print(0)
# Out:
# 0

# %%
print(a,b,c)
# Out:
# apple banana cherry

# %%
a = 10
b = 2
c = 24

print(a + b + c)
# Out:
# 36

# %%
temp = 25
a = 10
b = 20

print(temp)
print(a)
print(b)
# Out:
# 25
# 10
# 20

# %%
a = 10
b = 20

temp = a
a = b
b = temp

print(temp)
# Out:
# 10

# %%
price = 100
quantity = 5
total = price * quantity
print(total)
# Out:
# 500

# %%
name = "Hayathulla khan"
print("Hello",name)
# Out:
# Hello Hayathulla khan

# %%
name = 'hayath'
print('Welcome',name)
print(name)
print(type(name))
# Out:
# Welcome hayath
# hayath
# <class 'str'>

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
x = 5
y = 2
print(x/y)
# Out:
# 2.5

# %%
name = 'hello'
name2 = "hello"
print(type(name))
print(type(name2))
# Out:
# <class 'str'>
# <class 'str'>

# %%
fruits = ["mango", "orange", "banana"]
print(fruits)
# Out:
# ['mango', 'orange', 'banana']

# %%
age = 25
print(type(age))
# Out:
# <class 'int'>

# %%
price = 234.23
print(type(price))
# Out:
# <class 'float'>

# %%
is_active = True
print(type(is_active))
# Out:
# <class 'bool'>

# %%
numbers = [1,2,3,4,5]
print(type(numbers))
# Out:
# <class 'list'>

# %%
numbers = [10,20,30,40,50]
print(numbers)
print(numbers[3])
# Out:
# [10, 20, 30, 40, 50]
# 40

# %%
fruits = ["apple", "mango", "banana"]
print(fruits)
# Out:
# ['apple', 'mango', 'banana']

# %%
num1 = [213,894,873,879,23,903,324,642,623,234,53]
print(num1[6])
# Out:
# 324

# %%
num2 = ["Apple", "Banana", "Mango", "Orange", "Grapes", "Strawberry", "Watermelon", "Pineapple", "Papaya", "Pear", "Kiwi", "Cherry", "Blueberry", "Pomegranate", "Avocado", "Coconut", "Lemon", "Lime", "Peach", "Plum", "Fig", "Grapefruit", "Dragon Fruit"]
print(num2[10],num2[11])
print(num2[2])
print(num2[3],num2[4],num2[5],num2[6])
# Out:
# Kiwi Cherry
# Mango
# Orange Grapes Strawberry Watermelon

# %%
print(num2[7],num2[8],num2[9],num2[10],num2[11],num2[12])
# Out:
# Pineapple Papaya Pear Kiwi Cherry Blueberry

# %%
numbers = [10,20,30,]
print(numbers)
print(numbers[1])
# Out:
# [10, 20, 30]
# 20

# %%
numbers.append(40)
print(numbers)
# Out:
# [10, 20, 30, 40]

# %%
numbers.remove(20)
print(numbers)
# Out:
# [10, 30, 40]

# %%
print(len(numbers))
# Out:
# 3

# %%
numbers.append(5)
print(numbers)
# Out:
# [10, 30, 40, 5]

# %%
print(len(numbers))
# Out:
# 4

# %%
print(numbers)
# Out:
# [10, 30, 40, 5]

# %%
numbers.remove(10)
numbers.remove(30)
numbers.remove(40)
numbers.remove(5)

# %%
print(len(numbers))
# Out:
# 0

# %%
print(numbers)
# Out:
# []

# %%
numbers.append(10)
numbers.append(20)
numbers.append(30)
numbers.append(40)
numbers.append(50)
numbers.append(60)
print(numbers)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
print(len(numbers))
# Out:
# 6

# %%
print(numbers[5])
# Out:
# 60
